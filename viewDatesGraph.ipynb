# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
import matplotlib.pyplot as plt
import numpy as np
import csv


ruta = 'viewDates.csv'
df = pd.read_csv(ruta)
df.head()
# Out:
#    viewYear
# 0      2003
# 1      2004
# 2      2004
# 3      2005
# 4      2004

# %%
df.tail()
# Out:
#          viewYear
# 3768685      2005
# 3768686      2005
# 3768687      2005
# 3768688      2005
# 3768689      2005

# %%
df.dtypes
# Out:
# viewYear    int64
# dtype: object

# %%
df.describe()
# Out:
#            viewYear
# count  3.768690e+06
# mean   2.004212e+03
# std    1.042463e+00
# min    1.999000e+03
# 25%    2.004000e+03
# 50%    2.005000e+03
# 75%    2.005000e+03
# max    2.005000e+03

# %%
print(df["viewYear"].value_counts())
df.hist(column = "viewYear", grid=False)
# Out:
# 2005    1899210
# 2004    1214386
# 2003     360173
# 2002     180149
# 2001      78897
# 2000      35801
# 1999         74
# Name: viewYear, dtype: int64
# array([[<AxesSubplot:title={'center':'viewYear'}>]], dtype=object)
