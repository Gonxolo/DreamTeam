# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
ruta = "movie_titles_vCorta.csv"
df = pd.read_csv(ruta, error_bad_lines=False)
df.head()
# Out:
# b'Skipping line 40: expected 3 fields, saw 4\nSkipping line 204: expected 3 fields, saw 4\nSkipping line 280: expected 3 fields, saw 4\nSkipping line 355: expected 3 fields, saw 4\nSkipping line 366: expected 3 fields, saw 4\nSkipping line 406: expected 3 fields, saw 4\nSkipping line 408: expected 3 fields, saw 4\nSkipping line 452: expected 3 fields, saw 4\n'
#    id_movie  year                       movie
# 0         3  1997                   Character
# 1         5  2004    The Rise and Fall of ECW
# 2         6  1997                        Sick
# 3         7  1992                       8 Man
# 4         8  2004  What the #$*! Do We Know!?

# %%
df.tail()
# Out:
#      id_movie  year                              movie
# 487       803  2001                      Soul Assassin
# 488       804  1944  Sherlock Holmes: The Scarlet Claw
# 489       806  1960                Eyes Without a Face
# 490       807  1959              The Mouse That Roared
# 491       808  1998                 Dead Man on Campus

# %%
cabecera = ["id_movie", "year", "movie"]
df.columns = cabecera
df.head()
# Out:
#    id_movie  year                       movie
# 0         3  1997                   Character
# 1         5  2004    The Rise and Fall of ECW
# 2         6  1997                        Sick
# 3         7  1992                       8 Man
# 4         8  2004  What the #$*! Do We Know!?

# %%
df.dtypes
# Out:
# id_movie     int64
# year         int64
# movie       object
# dtype: object

# %%
df.describe()
# Out:
#          id_movie         year
# count  492.000000   492.000000
# mean   415.093496  1989.310976
# std    231.653042    16.475460
# min      3.000000  1918.000000
# 25%    211.500000  1983.000000
# 50%    415.500000  1996.000000
# 75%    622.750000  2001.000000
# max    808.000000  2005.000000

# %%
df.describe(include = "all")
# Out:
#           id_movie         year       movie
# count   492.000000   492.000000         492
# unique         NaN          NaN         491
# top            NaN          NaN  Crash Dive
# freq           NaN          NaN           2
# mean    415.093496  1989.310976         NaN
# std     231.653042    16.475460         NaN
# min       3.000000  1918.000000         NaN
# 25%     211.500000  1983.000000         NaN
# 50%     415.500000  1996.000000         NaN
# 75%     622.750000  2001.000000         NaN
# max     808.000000  2005.000000         NaN

# %%
print(df["year"].value_counts())
df.hist(column = "year", grid=False)
# Out:
# 2002    35
# 2004    34
# 2000    33
# 2003    27
# 2001    26
#         ..
# 1948     1
# 1950     1
# 1955     1
# 1956     1
# 1918     1
# Name: year, Length: 67, dtype: int64
# array([[<AxesSubplot:title={'center':'year'}>]], dtype=object)

# %%
print(df["id_movie"].value_counts())
df.hist(column = "id_movie", grid=False)
# Out:
# 808    1
# 275    1
# 280    1
# 281    1
# 283    1
#       ..
# 552    1
# 553    1
# 555    1
# 556    1
# 3      1
# Name: id_movie, Length: 492, dtype: int64
# array([[<AxesSubplot:title={'center':'id_movie'}>]], dtype=object)

# %%
df["movie"].value_counts()
# Out:
# Crash Dive                                                              2
# High Fidelity                                                           1
# The Rise and Fall of ECW                                                1
# Peter Jennings Reports: The Kennedy Assassination: Beyond Conspiracy    1
# Journey to the Center of the Earth                                      1
#                                                                        ..
# My Side of the Mountain                                                 1
# Care Bears: Journey to Joke-a-Lot                                       1
# A Slipping Down Life                                                    1
# Rambo: First Blood Part II                                              1
# Cardcaptor Sakura: The Movie                                            1
# Name: movie, Length: 491, dtype: int64

# %%
fig, ax = plt.subplots()
df["movie"].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Ticket'].value_counts()
# Out:
# 347082                7
# CA. 2343              7
# 1601                  7
# 3101295               6
# CA 2144               6
#                      ..
# SOTON/O.Q. 3101310    1
# PP 4348               1
# PC 17473              1
# 349231                1
# A/5 2817              1
# Name: Ticket, Length: 681, dtype: int64

# %%
fig, ax = plt.subplots()
df['Ticket'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Cabina'].value_counts()
# Out:
# C23 C25 C27    4
# G6             4
# B96 B98        4
# F33            3
# D              3
#               ..
# E63            1
# C49            1
# E46            1
# F G63          1
# B82 B84        1
# Name: Cabina, Length: 147, dtype: int64

# %%
fig, ax = plt.subplots()
df['Cabina'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Embarque'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarque, dtype: int64

# %%
fig, ax = plt.subplots()
df['Embarque'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'edad', grid=False)
# Out:
# <AxesSubplot:>

# %%
df2 = df[df.edad < 100]
df2.boxplot(column = 'edad', grid=False)
# Out:
# <AxesSubplot:>

# %%
df.hist(column = 'edad', grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'edad'}>]], dtype=object)

# %%
df.boxplot(column = 'Hermanos/Pareja', grid=False)
df.hist(column = 'Hermanos/Pareja', grid=False)
print(df['Hermanos/Pareja'].value_counts())
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: Hermanos/Pareja, dtype: int64

# %%
df.boxplot(column = 'Hijos/Padres', grid=False)
df.hist(column = 'Hijos/Padres', grid=False)
print(df['Hijos/Padres'].value_counts())
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Hijos/Padres, dtype: int64

# %%
df.boxplot(column = 'Tarifa', grid=False)
df.hist(column = 'Tarifa', grid=False)
print(df['Tarifa'].value_counts())
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 8.4583      1
# 9.8375      1
# 8.3625      1
# 14.1083     1
# 17.4000     1
# Name: Tarifa, Length: 248, dtype: int64

# %%
columnas = list(df)
for columna in columnas:
    print("Cantidad de datos sin " + columna + ": " + str(len(df) - df[columna].count()))
    print(str(np.round((len(df) - df[columna].count())/float(len(df))*100,2))+"%")
    print("-------")
# Out:
# Cantidad de datos sin ID: 0
# 0.0%
# -------
# Cantidad de datos sin Sobrevivio: 0
# 0.0%
# -------
# Cantidad de datos sin Clase: 0
# 0.0%
# -------
# Cantidad de datos sin Nombre: 0
# 0.0%
# -------
# Cantidad de datos sin Sexo: 0
# 0.0%
# -------
# Cantidad de datos sin edad: 177
# 19.87%
# -------
# Cantidad de datos sin Hermanos/Pareja: 0
# 0.0%
# -------
# Cantidad de datos sin Hijos/Padres: 0
# 0.0%
# -------
# Cantidad de datos sin Ticket: 0
# 0.0%
# -------
# Cantidad de datos sin Tarifa: 0
# 0.0%
# -------
# Cantidad de datos sin Cabina: 687
# 77.1%
# -------
# Cantidad de datos sin Embarque: 2
# 0.22%
# -------

# %%
df.head()
# Out:
#    ID  Sobrevivio  Clase                                             Nombre  \
# 0   1           0      3                            Braund, Mr. Owen Harris
# 1   2           1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3           1      3                             Heikkinen, Miss. Laina
# 3   4           1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5           0      3                           Allen, Mr. William Henry
#
#      Sexo  edad  Hermanos/Pareja  Hijos/Padres            Ticket   Tarifa  \
# 0    male  22.0                1             0         A/5 21171   7.2500
# 1  female  38.0                1             0          PC 17599  71.2833
# 2  female  26.0                0             0  STON/O2. 3101282   7.9250
# 3  female  35.0                1             0            113803  53.1000
# 4    male  35.0                0             0            373450   8.0500
#
#   Cabina Embarque
# 0    NaN        S
# 1    C85        C
# ...

# %%
df.dropna(axis=0)
# Out:
#       ID  Sobrevivio  Clase  \
# 1      2           1      1
# 3      4           1      1
# 6      7           0      1
# 10    11           1      3
# 11    12           1      1
# ..   ...         ...    ...
# 871  872           1      1
# 872  873           0      1
# 879  880           1      1
# 887  888           1      1
# 889  890           1      1
#
#                                                 Nombre    Sexo  edad  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 6                              McCarthy, Mr. Timothy J    male  54.0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# ..                                                 ...     ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# ...

# %%
df.dropna(subset = ["Cabina"], axis = 0)
# Out:
#       ID  Sobrevivio  Clase  \
# 1      2           1      1
# 3      4           1      1
# 6      7           0      1
# 10    11           1      3
# 11    12           1      1
# ..   ...         ...    ...
# 871  872           1      1
# 872  873           0      1
# 879  880           1      1
# 887  888           1      1
# 889  890           1      1
#
#                                                 Nombre    Sexo  edad  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 6                              McCarthy, Mr. Timothy J    male  54.0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# ..                                                 ...     ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# ...

# %%
df.dropna(axis = 1)
# Out:
#       ID  Sobrevivio  Clase  \
# 0      1           0      3
# 1      2           1      1
# 2      3           1      3
# 3      4           1      1
# 4      5           0      3
# ..   ...         ...    ...
# 886  887           0      2
# 887  888           1      1
# 888  889           0      3
# 889  890           1      1
# 890  891           0      3
#
#                                                 Nombre    Sexo  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# ...

# %%
#Eliminaremos las filas sin datos en "edad" y "Embarque" y luego las columnas enteras que no tengan datos ("Cabina")
df2 = copy.copy(df)
df2.dropna(subset = ["edad"], axis = 0, inplace = True)
df2.dropna(subset = ["Embarque"], axis = 0, inplace = True)
df2.dropna(axis = 1, inplace = True)
df2
# Out:
#       ID  Sobrevivio  Clase  \
# 0      1           0      3
# 1      2           1      1
# 2      3           1      3
# 3      4           1      1
# 4      5           0      3
# ..   ...         ...    ...
# 885  886           0      3
# 886  887           0      2
# 887  888           1      1
# 889  890           1      1
# 890  891           0      3
#
#                                                 Nombre    Sexo  edad  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0
# ...

# %%
df2.describe()
# Out:
#                ID  Sobrevivio       Clase        edad  Hermanos/Pareja  \
# count  712.000000  712.000000  712.000000  712.000000       712.000000
# mean   448.589888    0.404494    2.240169   29.920183         0.514045
# std    258.683191    0.491139    0.836854   16.150868         0.930692
# min      1.000000    0.000000    1.000000    0.420000         0.000000
# 25%    222.750000    0.000000    1.000000   20.000000         0.000000
# 50%    445.000000    0.000000    2.000000   28.000000         0.000000
# 75%    677.250000    1.000000    3.000000   38.000000         1.000000
# max    891.000000    1.000000    3.000000  220.000000         5.000000
#
#        Hijos/Padres      Tarifa
# count    712.000000  712.000000
# mean       0.432584   34.567251
# std        0.854181   52.938648
# min        0.000000    0.000000
# 25%        0.000000    8.050000
# 50%        0.000000   15.645850
# 75%        1.000000   33.000000
# max        6.000000  512.329200

# %%
df2 = df2[df2.edad < 100]
df2.describe()
# Out:
#                ID  Sobrevivio       Clase        edad  Hermanos/Pareja  \
# count  711.000000  711.000000  711.000000  711.000000       711.000000
# mean   448.392405    0.405063    2.239100   29.652841         0.514768
# std    258.811584    0.491250    0.836957   14.500296         0.931147
# min      1.000000    0.000000    1.000000    0.420000         0.000000
# 25%    222.500000    0.000000    1.000000   20.000000         0.000000
# 50%    444.000000    0.000000    2.000000   28.000000         0.000000
# 75%    677.500000    1.000000    3.000000   38.000000         1.000000
# max    891.000000    1.000000    3.000000   80.000000         5.000000
#
#        Hijos/Padres      Tarifa
# count    711.000000  711.000000
# mean       0.433193   34.604547
# std        0.854628   52.966554
# min        0.000000    0.000000
# 25%        0.000000    8.050000
# 50%        0.000000   15.741700
# 75%        1.000000   33.000000
# max        6.000000  512.329200

# %%
# Reemplazar datos
df3 = df
promedio_edad = df3["edad"].mean()
print(promedio_edad)
# Out:
# 29.97642857142857

# %%
df3["edad"].replace(np.nan, promedio_edad, inplace=True)
df3.describe()
# Out:
#                ID  Sobrevivio       Clase        edad  Hermanos/Pareja  \
# count  891.000000  891.000000  891.000000  891.000000       891.000000
# mean   446.000000    0.383838    2.308642   29.976429         0.523008
# std    257.353842    0.486592    0.836071   14.478069         1.102743
# min      1.000000    0.000000    1.000000    0.420000         0.000000
# 25%    223.500000    0.000000    2.000000   22.000000         0.000000
# 50%    446.000000    0.000000    3.000000   29.976429         0.000000
# 75%    668.500000    1.000000    3.000000   35.000000         1.000000
# max    891.000000    1.000000    3.000000  220.000000         8.000000
#
#        Hijos/Padres      Tarifa
# count    891.000000  891.000000
# mean       0.381594   32.204208
# std        0.806057   49.693429
# min        0.000000    0.000000
# 25%        0.000000    7.910400
# 50%        0.000000   14.454200
# 75%        0.000000   31.000000
# max        6.000000  512.329200
